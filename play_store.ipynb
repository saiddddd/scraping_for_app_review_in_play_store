# %%
from google_play_scraper import app
import pandas as pd

# %%
from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'com.pegadaiandigital',
    sleep_milliseconds=0, # defaults to 0
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    filter_score_with=5 # defaults to None(means all score) ya, skornya 1-1 aja dulu yaaa...
)

# %%
reviewid = []
username =[]
comment = []
jml_komen_disukai = []
score = []
waktu = []
user_image = []
for i in range(len(result)):
    reviewid.append(result[i]['reviewId'])
    username.append(result[i]['userName'])
    comment.append(result[i]['content'])
    jml_komen_disukai.append(result[i]["thumbsUpCount"])
    score.append(result[i]["score"])
    waktu.append(result[i]["at"])
    user_image.append(result[i]["userImage"])

# %%
df = pd.DataFrame(list(zip(reviewid, user_image, username, comment, jml_komen_disukai, score, waktu)),
               columns =['review_id', 'user_image','nama_user', 'komentar', 'jml_komen_disukai', 'rating', 'waktu'])

# %%
df
# Out:
#                                              review_id  \
# 0    gp:AOqpTOHzDHvEARuBgTE2F_Aw2k3wotNtekTqdao7ucJ...
# 1    gp:AOqpTOEefYhHQXwi1fp_VyuJppTCuHq0jCOoQI9kBWL...
# 2    gp:AOqpTOEgmFskBAsMtfqAbJIJrn-GLtCslicmdo3_0UI...
# 3    gp:AOqpTOGuk2xVH7-CUHlW7UtQBIwdwGdg_V84DOkz_Aa...
# 4    gp:AOqpTOFaKcqBXtAYTsT_Gt2s0EGpxmo5HD1vE9rN7vH...
# ..                                                 ...
# 393  gp:AOqpTOHye3-Lo5jvEkNvGL1Vg35q0E1si70KwTczgPq...
# 394  gp:AOqpTOHSxrM5zRvuHE37CNGMJ3kryq01YoxPFQAUIFQ...
# 395  gp:AOqpTOE6ZQaEGwBPzSgkLzJS5BvbM0fD9eQtARzjAhC...
# 396  gp:AOqpTOHP53oFNv5AVwKYCXKipjRYvtPc5TQoJmxTkzr...
# 397  gp:AOqpTOFGG5Ds6qE0-nzAMqPRaK-i8vM1jOSPWJofzAM...
#
#                                             user_image  \
# 0    https://play-lh.googleusercontent.com/a/AATXAJ...
# 1    https://play-lh.googleusercontent.com/a/AATXAJ...
# 2    https://play-lh.googleusercontent.com/a-/AOh14...
# 3    https://play-lh.googleusercontent.com/a-/AOh14...
# 4    https://play-lh.googleusercontent.com/a-/AOh14...
# ..                                                 ...
# 393  https://play-lh.googleusercontent.com/a-/AOh14...
# 394  https://play-lh.googleusercontent.com/a-/AOh14...
# 395  https://play-lh.googleusercontent.com/a-/AOh14...
# 396  https://play-lh.googleusercontent.com/a-/AOh14...
# 397  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                            nama_user  \
# 0                    Willy Maariwuth
# 1    Anugraini Perdana Putri Firdaus
# 2                        Denny Wahyu
# 3                     joshua renaldo
# 4                     Fahria Rahmani
# ..                               ...
# 393                        I'm human
# 394                  Rivaldi Pratama
# 395                 Delin Fitrianisa
# 396                  Kenzie Deangelo
# 397                   Nurul Shiraana
#
#                                               komentar  jml_komen_disukai  \
# 0    interesting application, very easy to use, no ...                  2
# 1    This is the easiest application ever, you can ...                  3
# 2    The interface is user friendly. I like the fea...                  9
# 3    Great! Easy to use app. Very user friendly. yo...                  7
# 4    this app very helpful,userfriendly, easy to us...                  3
# ..                                                 ...                ...
# 393  aplikasi mudah untuk diakses, mudah registrasi...                  0
# 394  Keren banget. Mulai dari tabungan emas, kredit...                  0
# 395  aku baru pertama kali investasi jual beli emas...                  0
# 396  Dari semua apps cmn yg ini paling satisfying. ...                  0
# 397  Aplikasinya sangat mudah digunakan dan sangat ...                  0
#
#      rating               waktu
# 0         5 2021-06-05 16:51:58
# 1         5 2021-06-03 17:58:50
# 2         5 2021-05-27 11:40:32
# 3         5 2021-05-29 11:25:13
# 4         5 2021-05-22 15:00:14
# ..      ...                 ...
# 393       5 2021-06-04 16:31:16
# 394       5 2021-06-02 11:15:16
# 395       5 2021-05-27 16:05:09
# 396       5 2021-06-07 20:28:01
# 397       5 2021-06-06 12:50:30
#
# [398 rows x 7 columns]
